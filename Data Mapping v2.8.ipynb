# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
print(pca.components_)
plt.plot(pca.components_[0])
# Out:
# [[ 0.02113023  0.01451965  0.01254874 ...  0.00337517  0.00384218
#    0.00304186]
#  [-0.02019148 -0.01583779 -0.0071751  ...  0.00656008  0.00274349
#    0.00208996]]

# %%
plt.plot(pca.components_[1])

# %%
pca.components_.shape
# Out:
# (2, 2375)

# %%
print(pca.explained_variance_)
# Out:
# [262.26421459 175.01865566]

# %%
df.shape
# Out:
# (2399, 36)

# %%
plt.plot(new_df.iloc[:2400,1])
plt.title('Temperature change of the first city, over approx. 100 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
plt.plot(new_df.iloc[:72,1])
plt.title('Temperature change of the first city, over approx. 3 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
plt.plot(df.iloc[:,35])
plt.title('Temperature change of the 35th city, over approx. 100 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
plt.plot(new_df.iloc[:2400,35])
plt.title('Temperature change of the 35th city, over approx. 100 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
plt.plot(new_df.iloc[:72,35])
plt.title('Temperature change of the 35th city, over approx. 3 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
for x in range(0, 35):
    plt.plot(new_df.iloc[:,x])
plt.title('Temperature change of all cities, over approx. 100 days')
plt.xlabel('Hours')
plt.ylabel('Temperature')
# Out:
# Text(0,0.5,'Temperature')

# %%
for x in range(0, 35):
    plt.figure()
    plt.title('Temperature change of city, over approx. 100 days')
    plt.xlabel('Hours')
    plt.ylabel('Temperature')
    plt.plot(new_df.iloc[:,x])
# Out:
# c:\users\lilone\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
#Creating new dataframe (called new_df_3) from new_df, consisting only of the first 3 days of temperature data for each city 
new_df_3 = new_df.iloc[:72]

#Creating new dataframe (called new_df_3) from new_df, consisting only of the first 3 days of temperature data for each city 
new_df_6 = new_df.iloc[:144]

# %%
#Temperature change of 35 cities, over approx. 3 days
fig, ax = plt.subplots(7, 5, sharex='col', sharey='row')
fig.subplots_adjust(bottom=1, right=4, top=5, wspace=0.5, hspace=0.5)

counter = 0

# axes are in a two-dimensional array, indexed by [row, col]
for i in range(7):
    for j in range(5):
        ax[i, j].plot(new_df_3.iloc[:, counter])
        counter += 1
        ax[i, j].set_ylabel('Temperature')
        ax[i, j].set_xlabel('Hours')

# %%
#Temperature change of 35 cities, over approx. 6 days
fig, ax = plt.subplots(7, 5, sharex='col', sharey='row')
fig.subplots_adjust(bottom=1, right=4, top=5, wspace=0.5, hspace=0.5)

counter = 0

# axes are in a two-dimensional array, indexed by [row, col]
for i in range(7):
    for j in range(5):
        ax[i, j].plot(new_df_6.iloc[:, counter])
        counter += 1
        ax[i, j].set_ylabel('Temperature')
        ax[i, j].set_xlabel('Hours')

# %%
for x in range(0, 35):
    plt.figure()
    plt.title('Temperature change of city, over approx. 3 days')
    plt.xlabel('Hours')
    plt.ylabel('Temperature')
    plt.plot(new_df.iloc[:72,x])

# %%
#Creating new dataframe (called df2) from new_df_3, consisting only of the first 3 days of temperature data for the first 33 cities
#in oder to get rid of the last 2 cities with questionable data 
df2 = new_df_3.iloc[:, :33]

# %%
plt.plot(pca.components_[0,:100])
plt.title('Plots the first PCA coefficient of the first 100 hours')
plt.xlabel('Hours')
plt.ylabel('PCA Coefficient 1')

# %%
plt.plot(pca.components_[1,:100])
plt.title('Plots the second PCA coefficient of the first 100 hours')
plt.xlabel('Hours')
plt.ylabel('PCA Coefficient 2')

# %%
#Create new principal components from df2 
pca2 = PCA(n_components=5)
pca2.fit(np.transpose(df2))

#Plot principal components from df2
print(pca2.components_)
plt.plot(pca2.components_[0])
plt.plot(pca2.components_[1])
plt.plot(pca2.components_[2])
plt.plot(pca2.components_[3])
plt.plot(pca2.components_[4])

# %%
#populating a dictionary with a1 and a2
dicts = {}
for x in range(0, 35): 
    a1 = np.dot(pca.components_[0], df[:,x]).T
    a2 = np.dot(pca.components_[1], df[:,x]).T
    dicts[a1] = a2

# %%
#populating a list with each a1 and a2
Coeffs = [] 
for x in range(0, 35): 
    a1 = np.dot(pca.components_[0], df[:,x]).T
    a2 = np.dot(pca.components_[1], df[:,x]).T
    Coeffs.append(a1)
    Coeffs.append(a2)

# %%
Coeffs

# %%
city_names = ['Vancouver', 'Portland', 'San Francisco', 'Seattle', 'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque', 'Denver', 'San Antonio', 'Dallas', 'Houston', 'Kansas City', 'Minneapolis', 'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis', 'Atlanta', 'Detroit', 'Jacksonville', 'Charlotte', 'Miami', 'Pittsburgh', 'Toronto', 'Philadelphia', 'New York', 'Montreal', 'Boston', 'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa', 'Nahariyya', 'Jerusalem']

# %%
city_names

# %%
def my_range(start, end, step):
    while start <= end:
        yield start
        start += step

zero = [Coeffs[0]]
one = [Coeffs[1]]

# %%
Z = np.empty((len(Coeffs), 2))
a = np.array(Coeffs) 

b = np.reshape(a, (-1, 2))
#This is the 2d array of the first 2 principal components of each city
b

# %%
#K-Means Clustering to visualize similarities 
from sklearn.cluster import KMeans
# Number of clusters
kmeans = KMeans(n_clusters=10)
# Fitting the input data
kmeans = kmeans.fit(b)
# Getting the cluster labels
labels = kmeans.predict(b)
# Centroid values
centroids = kmeans.cluster_centers_

# %%
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(b[:, 0], b[:, 0], c='#050505')
ax.scatter(centroids[:, 0], centroids[0, 1], marker='*', c='orange', s=1000)

# %%
labels = kmeans.labels_
labels

# %%
result = zip(b, kmeans.labels_)
sortedR = sorted(result, key=lambda b: b[1])
sortedR

# %%
import csv 

result2 = zip(sortedR, city_names)
#ba = (a for a in result2)
#print(ba)
#list(result2)
#type(result2)

#for i, (a, b) in enumerate(result2): 
#    print(i, a, b)
#This will display the resulting data structure consisting of the name, principal components and the position of the cluster of each city

tda = []
tda.append([])
with open('C:/Users/lilOne/Dropbox/Summer_2018/TrendMapper/Datasets/Weather/clusters.csv', 'w') as csvfile:
    clusterwriter = csv.writer(csvfile, delimiter=',')
    for i, (a, b) in enumerate(result2):
        print([i, a[0][0], a[0][1], b])
        tda.append([i, a[0][0], a[0][1], b])
tda

# %%
dfclusters = pd.DataFrame(kmeans.labels_, columns=['clusters'])

dfcities = pd.DataFrame(city_names, columns=['cities'])
dfcities 

dfclusters['cities'] = dfcities 
dfclusters

# %%
import googlemaps
import json 
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyA8ZOZ8EcTDVg8J7K7iuCWvMZY-VGUEKJQ')

# Geocoding Cities

#for place in city_names:
   # single_place = place.split('/')[0]
   # geocode = gmaps.geocode(city_names[2])
   # latlong = geocode[1]['geometry'][1]['location']
    
sLength = len(dfclusters['clusters'])    
dfclusters['lat'] = pd.Series(np.random.randn(sLength), index=dfclusters.index)
dfclusters['lng'] = pd.Series(np.random.randn(sLength), index=dfclusters.index)

for index, row in dfcities.iterrows():
    print(row['cities'])
    single_place = row['cities']
    geocode = gmaps.geocode(single_place)     
    print(geocode[0]["geometry"]["location"]) 
    latlong = geocode[0]["geometry"]["location"]
    dfclusters['lat'][index] = latlong['lat']
    dfclusters['lng'][index] = latlong['lng']

# %%
dfclusters

# %%
dfclusters['colors'] = pd.Series(np.random.randn(sLength), index=dfclusters.index)

#Adding color values to the dataframe 
for index, row in dfclusters.iterrows():
    if (row['clusters'] == 0):
        dfclusters['colors'][index] = '#084594'
    elif (row['clusters'] == 1):
        dfclusters['colors'][index] = '#2171b5'
    elif (row['clusters'] == 2):
        dfclusters['colors'][index] = '#4292c6'
    elif (row['clusters'] == 3):
        dfclusters['colors'][index] = '#6baed6'
    elif (row['clusters'] == 4):
        dfclusters['colors'][index] = '#9ecae1'
    elif (row['clusters'] == 5):
        dfclusters['colors'][index] = '#c6dbef'
    elif (row['clusters'] == 6):
        dfclusters['colors'][index] = '#deebf7'
    elif (row['clusters'] == 7):
        dfclusters['colors'][index] = '#f7fbff'
    elif (row['clusters'] == 8):
        dfclusters['colors'][index] = '#f7fbff'
    elif (row['clusters'] == 9):
        dfclusters['colors'][index] = '#f7fbff'
    else:
        dfclusters['colors'][index] = '#f7fbff'
dfclusters

# %%
from bokeh.plotting import figure, show, output_file
from bokeh.sampledata.us_cities import data as cities
from bokeh.sampledata.us_states import data as states
from bokeh.models import (GMapPlot, GMapOptions, ColumnDataSource, 
                          Circle, Range1d, PanTool, 
                          WheelZoomTool, BoxSelectTool, Select)
from bokeh.plotting import curdoc
from bokeh.layouts import layout, row, widgetbox
from bokeh.io import output_notebook

# %%
map_options = GMapOptions(lat=50.5020794, lng=111.9912878, 
                          map_type='roadmap', zoom=3)

# %%
api_key = 'AIzaSyA8ZOZ8EcTDVg8J7K7iuCWvMZY-VGUEKJQ'

# %%
plot = GMapPlot(x_range=Range1d(),
                y_range=Range1d(),
                map_options=map_options,
                api_key=api_key)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

# %%
from bokeh.palettes import Spectral6
from bokeh.transform import linear_cmap

x = [0,1,2,3,4,5,7,8,9]
y = [0,1,2,3,4,5,7,8,9]

mapper = linear_cmap(field_name='y', palette=Spectral6 ,low=min(y) ,high=max(y))

C = ['#084594','#2171b5','#4292c6', '#6baed6', '#9ecae1', '#c6dbef', '#deebf7', '#f7fbff', '#f7fbff', '#f7fbff', '#f7fbff']

        
group = dfclusters.groupby('cities')
source = ColumnDataSource(data=dict(lat = dfclusters['lat'],
                                   lon = dfclusters['lng'],
                                   color = dfclusters['colors']))

scale = 2.5 

circle = Circle(x="lon",
                y="lat",
                size=10,
                fill_color="color",
                fill_alpha=0.5)

plot.add_glyph(source, circle)
plot.add_tools(WheelZoomTool())

output_notebook()
show(plot)
